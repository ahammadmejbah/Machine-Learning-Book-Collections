# %% [markdown]
# # Import

# %%
import ast
import itertools
import json
import numpy as np
import pandas as pd
from pandas_common import *

# %%
config_pandas_display()

# %%
df = pd.DataFrame(data=
                     {'integers': [1, 2, 3, 4, 5], 
                      'floats': [-2.0, -1.0, 0, 1, 1.5], 
                      'integer_array': [[1, 2], ['1', 2], ['1', '2'], [3, 4, 5], [6, 7, 8, 9]], 
                      'str_array': [[], '[]', {}, '{}', ['a','b']],
                      'str_array2': [[], '[]', {}, ["'a'"], ["'a'","'b'"]],
                      'literal_str_array': "[[], ['a'], ['a','b'], '[]', {}]", 
                      'literal_str_array2': '"[[], [a], [a,b], \'[]\', {}]"', 
                      'nones': ['null', '', 'NaN', None, 'None'],
                      'strs': ['a', 'b', 'c', 'd', 'e']
                     })

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 9 columns):
# integers              5 non-null int64
# floats                5 non-null float64
# integer_array         5 non-null object
# str_array             5 non-null object
# str_array2            5 non-null object
# literal_str_array     5 non-null object
# literal_str_array2    5 non-null object
# nones                 4 non-null object
# strs                  5 non-null object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 440.0+ bytes

# %%
df
# Out:
#    integers  floats integer_array str_array  str_array2  \
# 0  1        -2.0     [1, 2]        []        []
# 1  2        -1.0     [1, 2]        []        []
# 2  3         0.0     [1, 2]        {}        {}
# 3  4         1.0     [3, 4, 5]     {}        ['a']
# 4  5         1.5     [6, 7, 8, 9]  [a, b]    ['a', 'b']
#
#                   literal_str_array            literal_str_array2 nones strs
# 0  [[], ['a'], ['a','b'], '[]', {}]  "[[], [a], [a,b], '[]', {}]"  null  a
# 1  [[], ['a'], ['a','b'], '[]', {}]  "[[], [a], [a,b], '[]', {}]"        b
# 2  [[], ['a'], ['a','b'], '[]', {}]  "[[], [a], [a,b], '[]', {}]"  NaN   c
# 3  [[], ['a'], ['a','b'], '[]', {}]  "[[], [a], [a,b], '[]', {}]"  None  d
# 4  [[], ['a'], ['a','b'], '[]', {}]  "[[], [a], [a,b], '[]', {}]"  None  e

# %% [markdown]
# # String => integer / float

# %%
df = pd.DataFrame(data={'integers': [1, "1", "'1'", '"1"']})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 1 columns):
# integers    4 non-null object
# dtypes: object(1)
# memory usage: 112.0+ bytes

# %%
df = add_type_columns(df)
df
# Out:
#   integers  integers_type
# 0  1        <class 'int'>
# 1  1        <class 'str'>
# 2  '1'      <class 'str'>
# 3  "1"      <class 'str'>

# %%
compare_all_list_items(df['integers'])
# Out:
#    item1  item2  comparison
# 0  1      '1'    False
# 1  1      "'1'"  False
# 2  1      '"1"'  False
# 3  '1'    "'1'"  False
# 4  '1'    '"1"'  False
# 5  "'1'"  '"1"'  False

# %% [markdown]
# #### Verify the output in csv file

# %%
df.to_csv('tmp-datatypes-int.csv', index=False)

# %%
tmp = pd.read_csv('tmp-datatypes-int.csv')
tmp
# Out:
#   integers  integers_type
# 0  1        <class 'int'>
# 1  1        <class 'str'>
# 2  '1'      <class 'str'>
# 3  "1"      <class 'str'>

# %% [markdown]
# #### Clean the string
#
# `strip()` > `replace()`

# %%
a = "'1'"
a = '"1"'
a = """1"""
a = ''"""'1'"""''
# a = a.replace("'", "").replace('"', "")
a = a.strip("'\"")
a
# Out:
# '1'

# %%
df
# Out:
#   integers  integers_type
# 0  1        <class 'int'>
# 1  1        <class 'str'>
# 2  '1'      <class 'str'>
# 3  "1"      <class 'str'>

# %%
# suffix = '_type'
# newColLoc = df.columns.get_loc('cleanse')+1
# newCol = 'cleanse'+suffix
# newColValue = df['cleanse'].apply(lambda x: type(x))
# df.insert(newColLoc, column=newCol, value=newColValue)

# %%
df['cleanse'] = df.apply(lambda x: convert_string_to_number(x['integers'], 'int'), axis=1)
df = add_type_columns(df)
df
# Out:
#   integers  integers_type  cleanse   cleanse_type
# 0  1        <class 'int'>  1        <class 'int'>
# 1  1        <class 'str'>  1        <class 'int'>
# 2  '1'      <class 'str'>  1        <class 'int'>
# 3  "1"      <class 'str'>  1        <class 'int'>

# %%
True | False
# Out:
# True

# %% [markdown]
# ## Float

# %%
df = pd.DataFrame(data={'floats': [1.0, '1.0', '"1.0"', "'1.0'", 1.000000000000001, 1.000000000000001]})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 1 columns):
# floats    6 non-null object
# dtypes: object(1)
# memory usage: 128.0+ bytes

# %%
df['cleanse'] = df.apply(lambda x: convert_string_to_number(x['floats'], 'float'), axis=1)
df = add_type_columns(df)
df
# Out:
#   floats      floats_type  cleanse     cleanse_type
# 0  1      <class 'float'>  1.0      <class 'float'>
# 1  1.0    <class 'str'>    1.0      <class 'float'>
# 2  "1.0"  <class 'str'>    1.0      <class 'float'>
# 3  '1.0'  <class 'str'>    1.0      <class 'float'>
# 4  1      <class 'float'>  1.0      <class 'float'>
# 5  1      <class 'float'>  1.0      <class 'float'>

# %%
compare_all_list_items(df['floats'])
# Out:
#                 item1              item2  comparison
# 0   1.0                '1.0'              False
# 1   1.0                '"1.0"'            False
# 2   1.0                "'1.0'"            False
# 3   1.0                1.000000000000001  False
# 4   1.0                1.000000000000001  False
# 5   '1.0'              '"1.0"'            False
# 6   '1.0'              "'1.0'"            False
# 7   '1.0'              1.000000000000001  False
# 8   '1.0'              1.000000000000001  False
# 9   '"1.0"'            "'1.0'"            False
# 10  '"1.0"'            1.000000000000001  False
# 11  '"1.0"'            1.000000000000001  False
# 12  "'1.0'"            1.000000000000001  False
# 13  "'1.0'"            1.000000000000001  False
# 14  1.000000000000001  1.000000000000001  True

# %%
df['cleanse'] = df.apply(lambda x: convert_string_to_number(x['floats'], 'float'), axis=1)
df = add_type_columns(df)
df
# Out:
#   floats      floats_type  cleanse     cleanse_type
# 0  1      <class 'float'>  1.0      <class 'float'>
# 1  1.0    <class 'str'>    1.0      <class 'float'>
# 2  "1.0"  <class 'str'>    1.0      <class 'float'>
# 3  '1.0'  <class 'str'>    1.0      <class 'float'>
# 4  1      <class 'float'>  1.0      <class 'float'>
# 5  1      <class 'float'>  1.0      <class 'float'>

# %% [markdown]
# # String => Boolean

# %%
df = pd.DataFrame(data={'bools': [True, 'True', '"True"', 1, False, 'False', '"False"', 0]})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 1 columns):
# bools    8 non-null object
# dtypes: object(1)
# memory usage: 144.0+ bytes

# %%
df = add_type_columns(df)
df
# Out:
#      bools      bools_type
# 0  True     <class 'bool'>
# 1  True     <class 'str'>
# 2  "True"   <class 'str'>
# 3  1        <class 'int'>
# 4  False    <class 'bool'>
# 5  False    <class 'str'>
# 6  "False"  <class 'str'>
# 7  0        <class 'int'>

# %%
int(True)
# Out:
# 1

# %%
compare_all_list_items(df['bools'])
# Out:
#         item1      item2  comparison
# 0   True       'True'     False
# 1   True       '"True"'   False
# 2   True       1          True
# 3   True       False      False
# 4   True       'False'    False
# 5   True       '"False"'  False
# 6   True       0          False
# 7   'True'     '"True"'   False
# 8   'True'     1          False
# 9   'True'     False      False
# 10  'True'     'False'    False
# 11  'True'     '"False"'  False
# 12  'True'     0          False
# 13  '"True"'   1          False
# 14  '"True"'   False      False
# 15  '"True"'   'False'    False
# 16  '"True"'   '"False"'  False
# 17  '"True"'   0          False
# 18  1          False      False
# 19  1          'False'    False
# 20  1          '"False"'  False
# 21  1          0          False
# 22  False      'False'    False
# 23  False      '"False"'  False
# 24  False      0          True
# 25  'False'    '"False"'  False
# 26  'False'    0          False
# 27  '"False"'  0          False

# %%
df['cleanse'] = df.apply(lambda x: convert_string_to_boolean(x['bools']), axis=1)
df = add_type_columns(df)
df
# Out:
#      bools      bools_type cleanse    cleanse_type
# 0  True     <class 'bool'>  True    <class 'bool'>
# 1  True     <class 'str'>   True    <class 'bool'>
# 2  "True"   <class 'str'>   True    <class 'bool'>
# 3  1        <class 'int'>   1       <class 'int'>
# 4  False    <class 'bool'>  False   <class 'bool'>
# 5  False    <class 'str'>   False   <class 'bool'>
# 6  "False"  <class 'str'>   False   <class 'bool'>
# 7  0        <class 'int'>   0       <class 'int'>

# %%
bool('False')
# Out:
# True

# %%
df['cleanse'] = df.apply(lambda x: convert_string_to_boolean(x['bools'], 'int'), axis=1)
df = add_type_columns(df)
df
# Out:
#      bools      bools_type  cleanse    cleanse_type
# 0  True     <class 'bool'>  1        <class 'bool'>
# 1  True     <class 'str'>   1        <class 'bool'>
# 2  "True"   <class 'str'>   1        <class 'bool'>
# 3  1        <class 'int'>   1        <class 'int'>
# 4  False    <class 'bool'>  0        <class 'bool'>
# 5  False    <class 'str'>   0        <class 'bool'>
# 6  "False"  <class 'str'>   0        <class 'bool'>
# 7  0        <class 'int'>   0        <class 'int'>

# %% [markdown]
# # String

# %%
df = pd.DataFrame(data={'strs': ['String contains a single quote(\') character', 
                                 'String contains a double quote(\") character',
                                 'String contains newline \newline',
                                 'String contains literal backslash (\\) character',
                                 'String contains ASCII horizontal tab \t character',
                                 'String contains ASCII bell (BEL) \a character',
                                 'String contains ASCII backspace (BS) \b character',
                                 'String contains ASCII formfeed (FF) \f character',
                                 'String contains ASCII linefeed (LF) \n character',
                                 'String contains ASCII carriage return (CR) \r character',
                                 'String contains ASCII vertical tab (VT) \v character',
                                 '''String contains a single (\') and a double (") quote''',
                                 '"String has inner double quotes"',
                                 "'String has inner single quotes'",
                                ]})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 1 columns):
# strs    14 non-null object
# dtypes: object(1)
# memory usage: 192.0+ bytes

# %%
df
# Out:
#                                                        strs
# 0   String contains a single quote(') character
# 1   String contains a double quote(") character
# 2   String contains newline \newline
# 3   String contains literal backslash (\) character
# 4   String contains ASCII horizontal tab \t character
# 5   String contains ASCII bell (BEL)  character
#  character
# 7   String contains ASCII formfeed (FF)
#  character
# 8   String contains ASCII linefeed (LF) \n character
# 9   String contains ASCII carriage return (CR) \r character
# 10  String contains ASCII vertical tab (VT)
#  character
# 11  String contains a single (') and a double (") quote
# 12  "String has inner double quotes"
# 13  'String has inner single quotes'

# %%
compare_all_list_items(df['strs'])
# Out:
#                                                         item1  \
# 0   "String contains a single quote(') character"
# 1   "String contains a single quote(') character"
# 2   "String contains a single quote(') character"
# 3   "String contains a single quote(') character"
# 4   "String contains a single quote(') character"
# 5   "String contains a single quote(') character"
# 6   "String contains a single quote(') character"
# 7   "String contains a single quote(') character"
# 8   "String contains a single quote(') character"
# 9   "String contains a single quote(') character"
# 10  "String contains a single quote(') character"
# 11  "String contains a single quote(') character"
# 12  "String contains a single quote(') character"
# 13  'String contains a double quote(") character'
# 14  'String contains a double quote(") character'
# 15  'String contains a double quote(") character'
# 16  'String contains a double quote(") character'
# 17  'String contains a double quote(") character'
# 18  'String contains a double quote(") character'
# 19  'String contains a double quote(") character'
# 20  'String contains a double quote(") character'
# 21  'String contains a double quote(") character'
# 22  'String contains a double quote(") character'
# 23  'String contains a double quote(") character'
# 24  'String contains a double quote(") character'
# 25  'String contains newline \newline'
# 26  'String contains newline \newline'
# 27  'String contains newline \newline'
# 28  'String contains newline \newline'
# 29  'String contains newline \newline'
# 30  'String contains newline \newline'
# 31  'String contains newline \newline'
# 32  'String contains newline \newline'
# 33  'String contains newline \newline'
# 34  'String contains newline \newline'
# 35  'String contains newline \newline'
# 36  'String contains literal backslash (\\) character'
# 37  'String contains literal backslash (\\) character'
# 38  'String contains literal backslash (\\) character'
# 39  'String contains literal backslash (\\) character'
# 40  'String contains literal backslash (\\) character'
# 41  'String contains literal backslash (\\) character'
# 42  'String contains literal backslash (\\) character'
# 43  'String contains literal backslash (\\) character'
# 44  'String contains literal backslash (\\) character'
# 45  'String contains literal backslash (\\) character'
# 46  'String contains ASCII horizontal tab \t character'
# 47  'String contains ASCII horizontal tab \t character'
# 48  'String contains ASCII horizontal tab \t character'
# 49  'String contains ASCII horizontal tab \t character'
# 50  'String contains ASCII horizontal tab \t character'
# 51  'String contains ASCII horizontal tab \t character'
# 52  'String contains ASCII horizontal tab \t character'
# 53  'String contains ASCII horizontal tab \t character'
# 54  'String contains ASCII horizontal tab \t character'
# 55  'String contains ASCII bell (BEL) \x07 character'
# 56  'String contains ASCII bell (BEL) \x07 character'
# 57  'String contains ASCII bell (BEL) \x07 character'
# 58  'String contains ASCII bell (BEL) \x07 character'
# 59  'String contains ASCII bell (BEL) \x07 character'
# 60  'String contains ASCII bell (BEL) \x07 character'
# 61  'String contains ASCII bell (BEL) \x07 character'
# 62  'String contains ASCII bell (BEL) \x07 character'
# 63  'String contains ASCII backspace (BS) \x08 character'
# 64  'String contains ASCII backspace (BS) \x08 character'
# 65  'String contains ASCII backspace (BS) \x08 character'
# 66  'String contains ASCII backspace (BS) \x08 character'
# 67  'String contains ASCII backspace (BS) \x08 character'
# 68  'String contains ASCII backspace (BS) \x08 character'
# 69  'String contains ASCII backspace (BS) \x08 character'
# 70  'String contains ASCII formfeed (FF) \x0c character'
# 71  'String contains ASCII formfeed (FF) \x0c character'
# 72  'String contains ASCII formfeed (FF) \x0c character'
# 73  'String contains ASCII formfeed (FF) \x0c character'
# 74  'String contains ASCII formfeed (FF) \x0c character'
# 75  'String contains ASCII formfeed (FF) \x0c character'
# 76  'String contains ASCII linefeed (LF) \n character'
# 77  'String contains ASCII linefeed (LF) \n character'
# 78  'String contains ASCII linefeed (LF) \n character'
# 79  'String contains ASCII linefeed (LF) \n character'
# 80  'String contains ASCII linefeed (LF) \n character'
# 81  'String contains ASCII carriage return (CR) \r character'
# 82  'String contains ASCII carriage return (CR) \r character'
# 83  'String contains ASCII carriage return (CR) \r character'
# 84  'String contains ASCII carriage return (CR) \r character'
# 85  'String contains ASCII vertical tab (VT) \x0b character'
# 86  'String contains ASCII vertical tab (VT) \x0b character'
# 87  'String contains ASCII vertical tab (VT) \x0b character'
# 88  'String contains a single (\') and a double (") quote'
# 89  'String contains a single (\') and a double (") quote'
# 90  '"String has inner double quotes"'
#
#                                                         item2  comparison
# 0   'String contains a double quote(") character'              False
# 1   'String contains newline \newline'                         False
# 2   'String contains literal backslash (\\) character'         False
# 3   'String contains ASCII horizontal tab \t character'        False
# 4   'String contains ASCII bell (BEL) \x07 character'          False
# 5   'String contains ASCII backspace (BS) \x08 character'      False
# 6   'String contains ASCII formfeed (FF) \x0c character'       False
# 7   'String contains ASCII linefeed (LF) \n character'         False
# 8   'String contains ASCII carriage return (CR) \r character'  False
# 9   'String contains ASCII vertical tab (VT) \x0b character'   False
# 10  'String contains a single (\') and a double (") quote'     False
# 11  '"String has inner double quotes"'                         False
# 12  "'String has inner single quotes'"                         False
# 13  'String contains newline \newline'                         False
# 14  'String contains literal backslash (\\) character'         False
# 15  'String contains ASCII horizontal tab \t character'        False
# 16  'String contains ASCII bell (BEL) \x07 character'          False
# 17  'String contains ASCII backspace (BS) \x08 character'      False
# 18  'String contains ASCII formfeed (FF) \x0c character'       False
# 19  'String contains ASCII linefeed (LF) \n character'         False
# 20  'String contains ASCII carriage return (CR) \r character'  False
# 21  'String contains ASCII vertical tab (VT) \x0b character'   False
# 22  'String contains a single (\') and a double (") quote'     False
# 23  '"String has inner double quotes"'                         False
# 24  "'String has inner single quotes'"                         False
# 25  'String contains literal backslash (\\) character'         False
# 26  'String contains ASCII horizontal tab \t character'        False
# 27  'String contains ASCII bell (BEL) \x07 character'          False
# 28  'String contains ASCII backspace (BS) \x08 character'      False
# 29  'String contains ASCII formfeed (FF) \x0c character'       False
# 30  'String contains ASCII linefeed (LF) \n character'         False
# 31  'String contains ASCII carriage return (CR) \r character'  False
# 32  'String contains ASCII vertical tab (VT) \x0b character'   False
# 33  'String contains a single (\') and a double (") quote'     False
# 34  '"String has inner double quotes"'                         False
# 35  "'String has inner single quotes'"                         False
# 36  'String contains ASCII horizontal tab \t character'        False
# 37  'String contains ASCII bell (BEL) \x07 character'          False
# 38  'String contains ASCII backspace (BS) \x08 character'      False
# 39  'String contains ASCII formfeed (FF) \x0c character'       False
# 40  'String contains ASCII linefeed (LF) \n character'         False
# 41  'String contains ASCII carriage return (CR) \r character'  False
# 42  'String contains ASCII vertical tab (VT) \x0b character'   False
# 43  'String contains a single (\') and a double (") quote'     False
# 44  '"String has inner double quotes"'                         False
# 45  "'String has inner single quotes'"                         False
# 46  'String contains ASCII bell (BEL) \x07 character'          False
# 47  'String contains ASCII backspace (BS) \x08 character'      False
# 48  'String contains ASCII formfeed (FF) \x0c character'       False
# 49  'String contains ASCII linefeed (LF) \n character'         False
# 50  'String contains ASCII carriage return (CR) \r character'  False
# 51  'String contains ASCII vertical tab (VT) \x0b character'   False
# 52  'String contains a single (\') and a double (") quote'     False
# 53  '"String has inner double quotes"'                         False
# 54  "'String has inner single quotes'"                         False
# 55  'String contains ASCII backspace (BS) \x08 character'      False
# 56  'String contains ASCII formfeed (FF) \x0c character'       False
# 57  'String contains ASCII linefeed (LF) \n character'         False
# 58  'String contains ASCII carriage return (CR) \r character'  False
# 59  'String contains ASCII vertical tab (VT) \x0b character'   False
# 60  'String contains a single (\') and a double (") quote'     False
# 61  '"String has inner double quotes"'                         False
# 62  "'String has inner single quotes'"                         False
# 63  'String contains ASCII formfeed (FF) \x0c character'       False
# 64  'String contains ASCII linefeed (LF) \n character'         False
# 65  'String contains ASCII carriage return (CR) \r character'  False
# 66  'String contains ASCII vertical tab (VT) \x0b character'   False
# 67  'String contains a single (\') and a double (") quote'     False
# 68  '"String has inner double quotes"'                         False
# 69  "'String has inner single quotes'"                         False
# 70  'String contains ASCII linefeed (LF) \n character'         False
# 71  'String contains ASCII carriage return (CR) \r character'  False
# 72  'String contains ASCII vertical tab (VT) \x0b character'   False
# 73  'String contains a single (\') and a double (") quote'     False
# 74  '"String has inner double quotes"'                         False
# 75  "'String has inner single quotes'"                         False
# 76  'String contains ASCII carriage return (CR) \r character'  False
# 77  'String contains ASCII vertical tab (VT) \x0b character'   False
# 78  'String contains a single (\') and a double (") quote'     False
# 79  '"String has inner double quotes"'                         False
# 80  "'String has inner single quotes'"                         False
# 81  'String contains ASCII vertical tab (VT) \x0b character'   False
# 82  'String contains a single (\') and a double (") quote'     False
# 83  '"String has inner double quotes"'                         False
# 84  "'String has inner single quotes'"                         False
# 85  'String contains a single (\') and a double (") quote'     False
# 86  '"String has inner double quotes"'                         False
# 87  "'String has inner single quotes'"                         False
# 88  '"String has inner double quotes"'                         False
# 89  "'String has inner single quotes'"                         False
# 90  "'String has inner single quotes'"                         False

# %%
df['cleanse'] = df.apply(lambda x: clean_string_literal(x['strs']), axis=1)
df
# Out:
#                                                        strs  \
# 0   String contains a single quote(') character
# 1   String contains a double quote(") character
# 2   String contains newline \newline
# 3   String contains literal backslash (\) character
# 4   String contains ASCII horizontal tab \t character
# 5   String contains ASCII bell (BEL)  character
#  character
# 7   String contains ASCII formfeed (FF)
#  character
# 8   String contains ASCII linefeed (LF) \n character
# 9   String contains ASCII carriage return (CR) \r character
# 10  String contains ASCII vertical tab (VT)
#  character
# 11  String contains a single (') and a double (") quote
# 12  "String has inner double quotes"
# 13  'String has inner single quotes'
#
#                                                     cleanse
# 0   String contains a single quote(') character
# 1   String contains a double quote(") character
# 2   String contains newline \newline
# 3   String contains literal backslash (\) character
# 4   String contains ASCII horizontal tab \t character
# 5   String contains ASCII bell (BEL)  character
#  character
# 7   String contains ASCII formfeed (FF)
#  character
# 8   String contains ASCII linefeed (LF) \n character
# 9   String contains ASCII carriage return (CR) \r character
# 10  String contains ASCII vertical tab (VT)
#  character
# 11  String contains a single (') and a double (") quote
# 12  String has inner double quotes
# 13  String has inner single quotes

# %% [markdown]
# # List

# %%
df = pd.DataFrame(data={'lists': [
    [],
    [1,2], ['1','2'],
    '[]', "[]",
    '[1,2]', "[1,2]",
    '"[1,2]"', '"[\'1\',\'2\']"',
    ['a','b'], "['a','b']", '"[\'a\',\'b\']"'
]})

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 1 columns):
# lists    12 non-null object
# dtypes: object(1)
# memory usage: 176.0+ bytes

# %%
df = add_type_columns(df)
df
# Out:
#           lists      lists_type
# 0   []           <class 'list'>
# 1   [1, 2]       <class 'list'>
# 2   [1, 2]       <class 'list'>
# 3   []           <class 'str'>
# 4   []           <class 'str'>
# 5   [1,2]        <class 'str'>
# 6   [1,2]        <class 'str'>
# 7   "[1,2]"      <class 'str'>
# 8   "['1','2']"  <class 'str'>
# 9   [a, b]       <class 'list'>
# 10  ['a','b']    <class 'str'>
# 11  "['a','b']"  <class 'str'>

# %%
compare_all_list_items(df['lists'])
# Out:
#                 item1              item2  comparison
# 0   []                 [1, 2]             False
# 1   []                 ['1', '2']         False
# 2   []                 '[]'               False
# 3   []                 '[]'               False
# 4   []                 '[1,2]'            False
# 5   []                 '[1,2]'            False
# 6   []                 '"[1,2]"'          False
# 7   []                 '"[\'1\',\'2\']"'  False
# 8   []                 ['a', 'b']         False
# 9   []                 "['a','b']"        False
# 10  []                 '"[\'a\',\'b\']"'  False
# 11  [1, 2]             ['1', '2']         False
# 12  [1, 2]             '[]'               False
# 13  [1, 2]             '[]'               False
# 14  [1, 2]             '[1,2]'            False
# 15  [1, 2]             '[1,2]'            False
# 16  [1, 2]             '"[1,2]"'          False
# 17  [1, 2]             '"[\'1\',\'2\']"'  False
# 18  [1, 2]             ['a', 'b']         False
# 19  [1, 2]             "['a','b']"        False
# 20  [1, 2]             '"[\'a\',\'b\']"'  False
# 21  ['1', '2']         '[]'               False
# 22  ['1', '2']         '[]'               False
# 23  ['1', '2']         '[1,2]'            False
# 24  ['1', '2']         '[1,2]'            False
# 25  ['1', '2']         '"[1,2]"'          False
# 26  ['1', '2']         '"[\'1\',\'2\']"'  False
# 27  ['1', '2']         ['a', 'b']         False
# 28  ['1', '2']         "['a','b']"        False
# 29  ['1', '2']         '"[\'a\',\'b\']"'  False
# 30  '[]'               '[]'               True
# 31  '[]'               '[1,2]'            False
# 32  '[]'               '[1,2]'            False
# 33  '[]'               '"[1,2]"'          False
# 34  '[]'               '"[\'1\',\'2\']"'  False
# 35  '[]'               ['a', 'b']         False
# 36  '[]'               "['a','b']"        False
# 37  '[]'               '"[\'a\',\'b\']"'  False
# 38  '[]'               '[1,2]'            False
# 39  '[]'               '[1,2]'            False
# 40  '[]'               '"[1,2]"'          False
# 41  '[]'               '"[\'1\',\'2\']"'  False
# 42  '[]'               ['a', 'b']         False
# 43  '[]'               "['a','b']"        False
# 44  '[]'               '"[\'a\',\'b\']"'  False
# 45  '[1,2]'            '[1,2]'            True
# 46  '[1,2]'            '"[1,2]"'          False
# 47  '[1,2]'            '"[\'1\',\'2\']"'  False
# 48  '[1,2]'            ['a', 'b']         False
# 49  '[1,2]'            "['a','b']"        False
# 50  '[1,2]'            '"[\'a\',\'b\']"'  False
# 51  '[1,2]'            '"[1,2]"'          False
# 52  '[1,2]'            '"[\'1\',\'2\']"'  False
# 53  '[1,2]'            ['a', 'b']         False
# 54  '[1,2]'            "['a','b']"        False
# 55  '[1,2]'            '"[\'a\',\'b\']"'  False
# 56  '"[1,2]"'          '"[\'1\',\'2\']"'  False
# 57  '"[1,2]"'          ['a', 'b']         False
# 58  '"[1,2]"'          "['a','b']"        False
# 59  '"[1,2]"'          '"[\'a\',\'b\']"'  False
# 60  '"[\'1\',\'2\']"'  ['a', 'b']         False
# 61  '"[\'1\',\'2\']"'  "['a','b']"        False
# 62  '"[\'1\',\'2\']"'  '"[\'a\',\'b\']"'  False
# 63  ['a', 'b']         "['a','b']"        False
# 64  ['a', 'b']         '"[\'a\',\'b\']"'  False
# 65  "['a','b']"        '"[\'a\',\'b\']"'  False

# %%
df['cleanse'] = df.apply(lambda x: clean_string_literal(x['lists']), axis=1)
df = add_type_columns(df)
df
# Out:
#           lists      lists_type    cleanse    cleanse_type
# 0   []           <class 'list'>  []         <class 'list'>
# 1   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>
# 2   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>
# 3   []           <class 'str'>   []         <class 'str'>
# 4   []           <class 'str'>   []         <class 'str'>
# 5   [1,2]        <class 'str'>   [1,2]      <class 'str'>
# 6   [1,2]        <class 'str'>   [1,2]      <class 'str'>
# 7   "[1,2]"      <class 'str'>   [1,2]      <class 'str'>
# 8   "['1','2']"  <class 'str'>   ['1','2']  <class 'str'>
# 9   [a, b]       <class 'list'>  [a, b]     <class 'list'>
# 10  ['a','b']    <class 'str'>   ['a','b']  <class 'str'>
# 11  "['a','b']"  <class 'str'>   ['a','b']  <class 'str'>

# %%
compare_all_list_items(df['cleanse'])
# Out:
#           item1        item2  comparison
# 0   []           [1, 2]       False
# 1   []           ['1', '2']   False
# 2   []           '[]'         False
# 3   []           '[]'         False
# 4   []           '[1,2]'      False
# 5   []           '[1,2]'      False
# 6   []           '[1,2]'      False
# 7   []           "['1','2']"  False
# 8   []           ['a', 'b']   False
# 9   []           "['a','b']"  False
# 10  []           "['a','b']"  False
# 11  [1, 2]       ['1', '2']   False
# 12  [1, 2]       '[]'         False
# 13  [1, 2]       '[]'         False
# 14  [1, 2]       '[1,2]'      False
# 15  [1, 2]       '[1,2]'      False
# 16  [1, 2]       '[1,2]'      False
# 17  [1, 2]       "['1','2']"  False
# 18  [1, 2]       ['a', 'b']   False
# 19  [1, 2]       "['a','b']"  False
# 20  [1, 2]       "['a','b']"  False
# 21  ['1', '2']   '[]'         False
# 22  ['1', '2']   '[]'         False
# 23  ['1', '2']   '[1,2]'      False
# 24  ['1', '2']   '[1,2]'      False
# 25  ['1', '2']   '[1,2]'      False
# 26  ['1', '2']   "['1','2']"  False
# 27  ['1', '2']   ['a', 'b']   False
# 28  ['1', '2']   "['a','b']"  False
# 29  ['1', '2']   "['a','b']"  False
# 30  '[]'         '[]'         True
# 31  '[]'         '[1,2]'      False
# 32  '[]'         '[1,2]'      False
# 33  '[]'         '[1,2]'      False
# 34  '[]'         "['1','2']"  False
# 35  '[]'         ['a', 'b']   False
# 36  '[]'         "['a','b']"  False
# 37  '[]'         "['a','b']"  False
# 38  '[]'         '[1,2]'      False
# 39  '[]'         '[1,2]'      False
# 40  '[]'         '[1,2]'      False
# 41  '[]'         "['1','2']"  False
# 42  '[]'         ['a', 'b']   False
# 43  '[]'         "['a','b']"  False
# 44  '[]'         "['a','b']"  False
# 45  '[1,2]'      '[1,2]'      True
# 46  '[1,2]'      '[1,2]'      True
# 47  '[1,2]'      "['1','2']"  False
# 48  '[1,2]'      ['a', 'b']   False
# 49  '[1,2]'      "['a','b']"  False
# 50  '[1,2]'      "['a','b']"  False
# 51  '[1,2]'      '[1,2]'      True
# 52  '[1,2]'      "['1','2']"  False
# 53  '[1,2]'      ['a', 'b']   False
# 54  '[1,2]'      "['a','b']"  False
# 55  '[1,2]'      "['a','b']"  False
# 56  '[1,2]'      "['1','2']"  False
# 57  '[1,2]'      ['a', 'b']   False
# 58  '[1,2]'      "['a','b']"  False
# 59  '[1,2]'      "['a','b']"  False
# 60  "['1','2']"  ['a', 'b']   False
# 61  "['1','2']"  "['a','b']"  False
# 62  "['1','2']"  "['a','b']"  False
# 63  ['a', 'b']   "['a','b']"  False
# 64  ['a', 'b']   "['a','b']"  False
# 65  "['a','b']"  "['a','b']"  True

# %%
json.loads(df.iloc[8,2])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-35-856e71d0398b> in <module>
# ----> 1 json.loads(df.iloc[8,2])
#
# ~/anaconda3/lib/python3.6/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352             parse_int is None and parse_float is None and
#     353             parse_constant is None and object_pairs_hook is None and not kw):
# --> 354         return _default_decoder.decode(s)
#     355     if cls is None:
#     356         cls = JSONDecoder
#
# ~/anaconda3/lib/python3.6/json/decoder.py in decode(self, s, _w)
#     337
#     338         """
# --> 339         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     340         end = _w(s, end).end()
#     341         if end != len(s):
#
# ~/anaconda3/lib/python3.6/json/decoder.py in raw_decode(self, s, idx)
#     355             obj, end = self.scan_once(s, idx)
#     356         except StopIteration as err:
# --> 357             raise JSONDecodeError("Expecting value", s, err.value) from None
#     358         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 2 (char 1)

# %% [markdown]
# **json.loads()** is unable to handle "['1','2']"

# %%
# ast.literal_eval("[a,b]".strip("'\""))
# json.loads("[a,b]".strip("'\""))

# %%
df['cleanse2'] = df.apply(lambda x: convert_string_to_DL(x['lists']), axis=1)
df = add_type_columns(df)
df
# Out:
#           lists      lists_type    cleanse    cleanse_type cleanse2  \
# 0   []           <class 'list'>  []         <class 'list'>  []
# 1   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>  [1, 2]
# 2   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>  [1, 2]
# 3   []           <class 'str'>   []         <class 'str'>   []
# 4   []           <class 'str'>   []         <class 'str'>   []
# 5   [1,2]        <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 6   [1,2]        <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 7   "[1,2]"      <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 8   "['1','2']"  <class 'str'>   ['1','2']  <class 'str'>   [1, 2]
# 9   [a, b]       <class 'list'>  [a, b]     <class 'list'>  [a, b]
# 10  ['a','b']    <class 'str'>   ['a','b']  <class 'str'>   [a, b]
# 11  "['a','b']"  <class 'str'>   ['a','b']  <class 'str'>   [a, b]
#
#      cleanse2_type
# 0   <class 'list'>
# 1   <class 'list'>
# 2   <class 'list'>
# 3   <class 'list'>
# 4   <class 'list'>
# 5   <class 'list'>
# 6   <class 'list'>
# 7   <class 'list'>
# 8   <class 'list'>
# 9   <class 'list'>
# 10  <class 'list'>
# 11  <class 'list'>

# %%
df['dumps'] = df.apply(lambda x: json.dumps(x['cleanse2']), axis=1)
df = add_type_columns(df)
df
# Out:
#           lists      lists_type    cleanse    cleanse_type cleanse2  \
# 0   []           <class 'list'>  []         <class 'list'>  []
# 1   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>  [1, 2]
# 2   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>  [1, 2]
# 3   []           <class 'str'>   []         <class 'str'>   []
# 4   []           <class 'str'>   []         <class 'str'>   []
# 5   [1,2]        <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 6   [1,2]        <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 7   "[1,2]"      <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 8   "['1','2']"  <class 'str'>   ['1','2']  <class 'str'>   [1, 2]
# 9   [a, b]       <class 'list'>  [a, b]     <class 'list'>  [a, b]
# 10  ['a','b']    <class 'str'>   ['a','b']  <class 'str'>   [a, b]
# 11  "['a','b']"  <class 'str'>   ['a','b']  <class 'str'>   [a, b]
#
#      cleanse2_type       dumps     dumps_type
# 0   <class 'list'>  []          <class 'str'>
# 1   <class 'list'>  [1, 2]      <class 'str'>
# 2   <class 'list'>  ["1", "2"]  <class 'str'>
# 3   <class 'list'>  []          <class 'str'>
# 4   <class 'list'>  []          <class 'str'>
# 5   <class 'list'>  [1, 2]      <class 'str'>
# 6   <class 'list'>  [1, 2]      <class 'str'>
# 7   <class 'list'>  [1, 2]      <class 'str'>
# 8   <class 'list'>  ["1", "2"]  <class 'str'>
# 9   <class 'list'>  ["a", "b"]  <class 'str'>
# 10  <class 'list'>  ["a", "b"]  <class 'str'>
# 11  <class 'list'>  ["a", "b"]  <class 'str'>

# %%
df['1st_item'] = df.apply(lambda x: x['cleanse2'][0] if len(x['cleanse2']) > 0 else None, axis=1)
df = add_type_columns(df)
df
# Out:
#           lists      lists_type    cleanse    cleanse_type cleanse2  \
# 0   []           <class 'list'>  []         <class 'list'>  []
# 1   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>  [1, 2]
# 2   [1, 2]       <class 'list'>  [1, 2]     <class 'list'>  [1, 2]
# 3   []           <class 'str'>   []         <class 'str'>   []
# 4   []           <class 'str'>   []         <class 'str'>   []
# 5   [1,2]        <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 6   [1,2]        <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 7   "[1,2]"      <class 'str'>   [1,2]      <class 'str'>   [1, 2]
# 8   "['1','2']"  <class 'str'>   ['1','2']  <class 'str'>   [1, 2]
# 9   [a, b]       <class 'list'>  [a, b]     <class 'list'>  [a, b]
# 10  ['a','b']    <class 'str'>   ['a','b']  <class 'str'>   [a, b]
# 11  "['a','b']"  <class 'str'>   ['a','b']  <class 'str'>   [a, b]
#
#      cleanse2_type       dumps     dumps_type 1st_item       1st_item_type
# 0   <class 'list'>  []          <class 'str'>  None     <class 'NoneType'>
# 1   <class 'list'>  [1, 2]      <class 'str'>  1        <class 'int'>
# 2   <class 'list'>  ["1", "2"]  <class 'str'>  1        <class 'str'>
# 3   <class 'list'>  []          <class 'str'>  None     <class 'NoneType'>
# 4   <class 'list'>  []          <class 'str'>  None     <class 'NoneType'>
# 5   <class 'list'>  [1, 2]      <class 'str'>  1        <class 'int'>
# 6   <class 'list'>  [1, 2]      <class 'str'>  1        <class 'int'>
# 7   <class 'list'>  [1, 2]      <class 'str'>  1        <class 'int'>
# 8   <class 'list'>  ["1", "2"]  <class 'str'>  1        <class 'str'>
# 9   <class 'list'>  ["a", "b"]  <class 'str'>  a        <class 'str'>
# 10  <class 'list'>  ["a", "b"]  <class 'str'>  a        <class 'str'>
# 11  <class 'list'>  ["a", "b"]  <class 'str'>  a        <class 'str'>

# %%
compare_all_list_items(df['cleanse2'])
# Out:
#          item1       item2  comparison
# 0   []          [1, 2]      False
# 1   []          ['1', '2']  False
# 2   []          []          True
# 3   []          []          True
# 4   []          [1, 2]      False
# 5   []          [1, 2]      False
# 6   []          [1, 2]      False
# 7   []          ['1', '2']  False
# 8   []          ['a', 'b']  False
# 9   []          ['a', 'b']  False
# 10  []          ['a', 'b']  False
# 11  [1, 2]      ['1', '2']  False
# 12  [1, 2]      []          False
# 13  [1, 2]      []          False
# 14  [1, 2]      [1, 2]      True
# 15  [1, 2]      [1, 2]      True
# 16  [1, 2]      [1, 2]      True
# 17  [1, 2]      ['1', '2']  False
# 18  [1, 2]      ['a', 'b']  False
# 19  [1, 2]      ['a', 'b']  False
# 20  [1, 2]      ['a', 'b']  False
# 21  ['1', '2']  []          False
# 22  ['1', '2']  []          False
# 23  ['1', '2']  [1, 2]      False
# 24  ['1', '2']  [1, 2]      False
# 25  ['1', '2']  [1, 2]      False
# 26  ['1', '2']  ['1', '2']  True
# 27  ['1', '2']  ['a', 'b']  False
# 28  ['1', '2']  ['a', 'b']  False
# 29  ['1', '2']  ['a', 'b']  False
# 30  []          []          True
# 31  []          [1, 2]      False
# 32  []          [1, 2]      False
# 33  []          [1, 2]      False
# 34  []          ['1', '2']  False
# 35  []          ['a', 'b']  False
# 36  []          ['a', 'b']  False
# 37  []          ['a', 'b']  False
# 38  []          [1, 2]      False
# 39  []          [1, 2]      False
# 40  []          [1, 2]      False
# 41  []          ['1', '2']  False
# 42  []          ['a', 'b']  False
# 43  []          ['a', 'b']  False
# 44  []          ['a', 'b']  False
# 45  [1, 2]      [1, 2]      True
# 46  [1, 2]      [1, 2]      True
# 47  [1, 2]      ['1', '2']  False
# 48  [1, 2]      ['a', 'b']  False
# 49  [1, 2]      ['a', 'b']  False
# 50  [1, 2]      ['a', 'b']  False
# 51  [1, 2]      [1, 2]      True
# 52  [1, 2]      ['1', '2']  False
# 53  [1, 2]      ['a', 'b']  False
# 54  [1, 2]      ['a', 'b']  False
# 55  [1, 2]      ['a', 'b']  False
# 56  [1, 2]      ['1', '2']  False
# 57  [1, 2]      ['a', 'b']  False
# 58  [1, 2]      ['a', 'b']  False
# 59  [1, 2]      ['a', 'b']  False
# 60  ['1', '2']  ['a', 'b']  False
# 61  ['1', '2']  ['a', 'b']  False
# 62  ['1', '2']  ['a', 'b']  False
# 63  ['a', 'b']  ['a', 'b']  True
# 64  ['a', 'b']  ['a', 'b']  True
# 65  ['a', 'b']  ['a', 'b']  True

# %%
df.to_csv('tmp-datatypes-list.csv', index=False)

# %% [markdown]
# # Dictionary

# %%
df = pd.DataFrame(data={'dicts': [
    {}, '{}',
    {'a':1, 'b':2}, 
    '{\'a\':1, \'b\':2}', "{'a':1, 'b':2}",
    '"{\'a\':1, \'b\':2}"', "'{\'a\':1, \'b\':2}'"
]})

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 1 columns):
# dicts    7 non-null object
# dtypes: object(1)
# memory usage: 136.0+ bytes

# %%
df = add_type_columns(df)
df
# Out:
#               dicts      dicts_type
# 0  {}                <class 'dict'>
# 1  {}                <class 'str'>
# 2  {'a': 1, 'b': 2}  <class 'dict'>
# 3  {'a':1, 'b':2}    <class 'str'>
# 4  {'a':1, 'b':2}    <class 'str'>
# 5  "{'a':1, 'b':2}"  <class 'str'>
# 6  '{'a':1, 'b':2}'  <class 'str'>

# %%
df.iloc[3,0] == df.iloc[4,0]
# Out:
# True

# %%
df['cleanse'] = df.apply(lambda x: clean_string_literal(x['dicts']), axis=1)
df = add_type_columns(df)
df
# Out:
#               dicts      dicts_type           cleanse    cleanse_type
# 0  {}                <class 'dict'>  {}                <class 'dict'>
# 1  {}                <class 'str'>   {}                <class 'str'>
# 2  {'a': 1, 'b': 2}  <class 'dict'>  {'a': 1, 'b': 2}  <class 'dict'>
# 3  {'a':1, 'b':2}    <class 'str'>   {'a':1, 'b':2}    <class 'str'>
# 4  {'a':1, 'b':2}    <class 'str'>   {'a':1, 'b':2}    <class 'str'>
# 5  "{'a':1, 'b':2}"  <class 'str'>   {'a':1, 'b':2}    <class 'str'>
# 6  '{'a':1, 'b':2}'  <class 'str'>   {'a':1, 'b':2}    <class 'str'>

# %%
df.to_csv('tmp-datatypes-dict.csv', index=False)

# %%
compare_all_list_items(df['dicts'])
# Out:
#                      item1                   item2  comparison
# 0   {}                      '{}'                    False
# 1   {}                      {'a': 1, 'b': 2}        False
# 2   {}                      "{'a':1, 'b':2}"        False
# 3   {}                      "{'a':1, 'b':2}"        False
# 4   {}                      '"{\'a\':1, \'b\':2}"'  False
# 5   {}                      "'{'a':1, 'b':2}'"      False
# 6   '{}'                    {'a': 1, 'b': 2}        False
# 7   '{}'                    "{'a':1, 'b':2}"        False
# 8   '{}'                    "{'a':1, 'b':2}"        False
# 9   '{}'                    '"{\'a\':1, \'b\':2}"'  False
# 10  '{}'                    "'{'a':1, 'b':2}'"      False
# 11  {'a': 1, 'b': 2}        "{'a':1, 'b':2}"        False
# 12  {'a': 1, 'b': 2}        "{'a':1, 'b':2}"        False
# 13  {'a': 1, 'b': 2}        '"{\'a\':1, \'b\':2}"'  False
# 14  {'a': 1, 'b': 2}        "'{'a':1, 'b':2}'"      False
# 15  "{'a':1, 'b':2}"        "{'a':1, 'b':2}"        True
# 16  "{'a':1, 'b':2}"        '"{\'a\':1, \'b\':2}"'  False
# 17  "{'a':1, 'b':2}"        "'{'a':1, 'b':2}'"      False
# 18  "{'a':1, 'b':2}"        '"{\'a\':1, \'b\':2}"'  False
# 19  "{'a':1, 'b':2}"        "'{'a':1, 'b':2}'"      False
# 20  '"{\'a\':1, \'b\':2}"'  "'{'a':1, 'b':2}'"      False

# %%
compare_all_list_items(df['cleanse'])
# Out:
#                item1             item2  comparison
# 0   {}                '{}'              False
# 1   {}                {'a': 1, 'b': 2}  False
# 2   {}                "{'a':1, 'b':2}"  False
# 3   {}                "{'a':1, 'b':2}"  False
# 4   {}                "{'a':1, 'b':2}"  False
# 5   {}                "{'a':1, 'b':2}"  False
# 6   '{}'              {'a': 1, 'b': 2}  False
# 7   '{}'              "{'a':1, 'b':2}"  False
# 8   '{}'              "{'a':1, 'b':2}"  False
# 9   '{}'              "{'a':1, 'b':2}"  False
# 10  '{}'              "{'a':1, 'b':2}"  False
# 11  {'a': 1, 'b': 2}  "{'a':1, 'b':2}"  False
# 12  {'a': 1, 'b': 2}  "{'a':1, 'b':2}"  False
# 13  {'a': 1, 'b': 2}  "{'a':1, 'b':2}"  False
# 14  {'a': 1, 'b': 2}  "{'a':1, 'b':2}"  False
# 15  "{'a':1, 'b':2}"  "{'a':1, 'b':2}"  True
# 16  "{'a':1, 'b':2}"  "{'a':1, 'b':2}"  True
# 17  "{'a':1, 'b':2}"  "{'a':1, 'b':2}"  True
# 18  "{'a':1, 'b':2}"  "{'a':1, 'b':2}"  True
# 19  "{'a':1, 'b':2}"  "{'a':1, 'b':2}"  True
# 20  "{'a':1, 'b':2}"  "{'a':1, 'b':2}"  True

# %%
df['cleanse2'] = df.apply(lambda x: convert_string_to_DL(x['dicts']), axis=1)
df = add_type_columns(df)
df
# Out:
#               dicts      dicts_type           cleanse    cleanse_type  \
# 0  {}                <class 'dict'>  {}                <class 'dict'>
# 1  {}                <class 'str'>   {}                <class 'str'>
# 2  {'a': 1, 'b': 2}  <class 'dict'>  {'a': 1, 'b': 2}  <class 'dict'>
# 3  {'a':1, 'b':2}    <class 'str'>   {'a':1, 'b':2}    <class 'str'>
# 4  {'a':1, 'b':2}    <class 'str'>   {'a':1, 'b':2}    <class 'str'>
# 5  "{'a':1, 'b':2}"  <class 'str'>   {'a':1, 'b':2}    <class 'str'>
# 6  '{'a':1, 'b':2}'  <class 'str'>   {'a':1, 'b':2}    <class 'str'>
#
#            cleanse2   cleanse2_type
# 0  {}                <class 'dict'>
# 1  {}                <class 'dict'>
# 2  {'a': 1, 'b': 2}  <class 'dict'>
# 3  {'a': 1, 'b': 2}  <class 'dict'>
# 4  {'a': 1, 'b': 2}  <class 'dict'>
# 5  {'a': 1, 'b': 2}  <class 'dict'>
# 6  {'a': 1, 'b': 2}  <class 'dict'>

# %% [markdown]
# # JSON

# %%
df = pd.DataFrame(data={'jsons': [
    {}, '{}',
    {'a':1, 'b':2}, {"a":1, "b":2},
    '{\'a\':1, \'b\':2}', "{'a':1, 'b':2}",
    '"{\'a\':1, \'b\':2}"', "'{\'a\':1, \'b\':2}'",
    [{}], '[{}]', "[{}]",
    [{'a':1, 'b':2}, {'c':3, 'd':4}], "[{'a':1, 'b':2}, {'c':3, 'd':4}]", ["{'a':1, 'b':2}", "{'c':3, 'd':4}"]
]})

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 1 columns):
# jsons    14 non-null object
# dtypes: object(1)
# memory usage: 192.0+ bytes

# %%
df['dumps'] = df.apply(lambda x: json.dumps(x['jsons']), axis=1)
df['dumps-loads'] = df.apply(lambda x: json.loads(json.dumps(x['jsons'])), axis=1)
df['cleanse'] = df.apply(lambda x: convert_string_to_DL(x['jsons']), axis=1)
df['dumps2'] = df.apply(lambda x: json.dumps(x['cleanse']), axis=1)
df['dumps-loads2'] = df.apply(lambda x: json.loads(json.dumps(x['cleanse'])), axis=1)
df = add_type_columns(df)
df
# Out:
#                                    jsons      jsons_type  \
# 0   {}                                    <class 'dict'>
# 1   {}                                    <class 'str'>
# 2   {'a': 1, 'b': 2}                      <class 'dict'>
# 3   {'a': 1, 'b': 2}                      <class 'dict'>
# 4   {'a':1, 'b':2}                        <class 'str'>
# 5   {'a':1, 'b':2}                        <class 'str'>
# 6   "{'a':1, 'b':2}"                      <class 'str'>
# 7   '{'a':1, 'b':2}'                      <class 'str'>
# 8   [{}]                                  <class 'list'>
# 9   [{}]                                  <class 'str'>
# 10  [{}]                                  <class 'str'>
# 11  [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]  <class 'list'>
# 12  [{'a':1, 'b':2}, {'c':3, 'd':4}]      <class 'str'>
# 13  [{'a':1, 'b':2}, {'c':3, 'd':4}]      <class 'list'>
#
#                                    dumps     dumps_type  \
# 0   {}                                    <class 'str'>
# 1   "{}"                                  <class 'str'>
# 2   {"a": 1, "b": 2}                      <class 'str'>
# 3   {"a": 1, "b": 2}                      <class 'str'>
# 4   "{'a':1, 'b':2}"                      <class 'str'>
# 5   "{'a':1, 'b':2}"                      <class 'str'>
# 6   "\"{'a':1, 'b':2}\""                  <class 'str'>
# 7   "'{'a':1, 'b':2}'"                    <class 'str'>
# 8   [{}]                                  <class 'str'>
# 9   "[{}]"                                <class 'str'>
# 10  "[{}]"                                <class 'str'>
# 11  [{"a": 1, "b": 2}, {"c": 3, "d": 4}]  <class 'str'>
# 12  "[{'a':1, 'b':2}, {'c':3, 'd':4}]"    <class 'str'>
# 13  ["{'a':1, 'b':2}", "{'c':3, 'd':4}"]  <class 'str'>
#
#                              dumps-loads dumps-loads_type  \
# 0   {}                                    <class 'dict'>
# 1   {}                                    <class 'str'>
# 2   {'a': 1, 'b': 2}                      <class 'dict'>
# 3   {'a': 1, 'b': 2}                      <class 'dict'>
# 4   {'a':1, 'b':2}                        <class 'str'>
# 5   {'a':1, 'b':2}                        <class 'str'>
# 6   "{'a':1, 'b':2}"                      <class 'str'>
# 7   '{'a':1, 'b':2}'                      <class 'str'>
# 8   [{}]                                  <class 'list'>
# 9   [{}]                                  <class 'str'>
# 10  [{}]                                  <class 'str'>
# 11  [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]  <class 'list'>
# 12  [{'a':1, 'b':2}, {'c':3, 'd':4}]      <class 'str'>
# 13  [{'a':1, 'b':2}, {'c':3, 'd':4}]      <class 'list'>
#
#                                  cleanse    cleanse_type  \
# 0   {}                                    <class 'dict'>
# 1   {}                                    <class 'dict'>
# 2   {'a': 1, 'b': 2}                      <class 'dict'>
# 3   {'a': 1, 'b': 2}                      <class 'dict'>
# 4   {'a': 1, 'b': 2}                      <class 'dict'>
# 5   {'a': 1, 'b': 2}                      <class 'dict'>
# 6   {'a': 1, 'b': 2}                      <class 'dict'>
# 7   {'a': 1, 'b': 2}                      <class 'dict'>
# 8   [{}]                                  <class 'list'>
# 9   [{}]                                  <class 'list'>
# 10  [{}]                                  <class 'list'>
# 11  [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]  <class 'list'>
# 12  [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]  <class 'list'>
# 13  [{'a':1, 'b':2}, {'c':3, 'd':4}]      <class 'list'>
#
#                                   dumps2    dumps2_type  \
# 0   {}                                    <class 'str'>
# 1   {}                                    <class 'str'>
# 2   {"a": 1, "b": 2}                      <class 'str'>
# 3   {"a": 1, "b": 2}                      <class 'str'>
# 4   {"a": 1, "b": 2}                      <class 'str'>
# 5   {"a": 1, "b": 2}                      <class 'str'>
# 6   {"a": 1, "b": 2}                      <class 'str'>
# 7   {"a": 1, "b": 2}                      <class 'str'>
# 8   [{}]                                  <class 'str'>
# 9   [{}]                                  <class 'str'>
# 10  [{}]                                  <class 'str'>
# 11  [{"a": 1, "b": 2}, {"c": 3, "d": 4}]  <class 'str'>
# 12  [{"a": 1, "b": 2}, {"c": 3, "d": 4}]  <class 'str'>
# 13  ["{'a':1, 'b':2}", "{'c':3, 'd':4}"]  <class 'str'>
#
#                             dumps-loads2 dumps-loads2_type
# 0   {}                                    <class 'dict'>
# 1   {}                                    <class 'dict'>
# 2   {'a': 1, 'b': 2}                      <class 'dict'>
# 3   {'a': 1, 'b': 2}                      <class 'dict'>
# 4   {'a': 1, 'b': 2}                      <class 'dict'>
# 5   {'a': 1, 'b': 2}                      <class 'dict'>
# 6   {'a': 1, 'b': 2}                      <class 'dict'>
# 7   {'a': 1, 'b': 2}                      <class 'dict'>
# 8   [{}]                                  <class 'list'>
# 9   [{}]                                  <class 'list'>
# 10  [{}]                                  <class 'list'>
# 11  [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]  <class 'list'>
# 12  [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}]  <class 'list'>
# 13  [{'a':1, 'b':2}, {'c':3, 'd':4}]      <class 'list'>

# %%
df.columns.get_loc('jsons')
# Out:
# 0

# %%
json.loads('{"a":1, "b":2}')
# Out:
# {'a': 1, 'b': 2}

# %%
json.dumps("{'a': 1, 'b': 2}")
# Out:
# '"{\'a\': 1, \'b\': 2}"'

# %%
df.to_csv('tmp-datatypes-json.csv', index=False)
